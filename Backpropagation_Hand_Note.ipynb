# %% [markdown]
# <a href="https://colab.research.google.com/github/DhimanTarafdar/AAA/blob/main/Backpropagation_Hand_Note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display

# Image display
display(Image("/content/image1.jpg", width=1200))
